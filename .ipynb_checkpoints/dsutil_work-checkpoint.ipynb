# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd


import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

# %matplotlib inline

from util import unet
from util import dsutil
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
unet_m = unet.unet_model()

# %%
X_train, Y_train = dsutil.get_train()
# Out:
# 100%|██████████| 670/670 [05:37<00:00,  2.99it/s]

# %%
X_test = dsutil.get_test()
# Out:
# 100%|██████████| 65/65 [00:00<00:00, 142.59it/s]

# %%
img = X_train[1]
plt.imshow(img)

# %%
# dsutil.convert_rgb_to_hsd_ndarray(img)

# %%
filter_nums = [16*min(2**i, 8) for i in range(5)]

# %%
import cv2
rev_img = dsutil.negpos_reverse(img)
plt.imshow(rev_img)

# %%
equ_r= cv2.equalizeHist(rev_img[:, :, 0])
equ_g = cv2.equalizeHist(rev_img[:, :, 1])
equ_b = cv2.equalizeHist(rev_img[:, :, 2])
plt.imshow(cv2.merge([equ_r, equ_g, equ_b]))

# %%
yuv_img = cv2.cvtColor(rev_img, cv2.COLOR_RGB2YUV)
yuv_img[:, :, 0] = cv2.equalizeHist(yuv_img[:, :, 0])
img_output = cv2.cvtColor(yuv_img, cv2.COLOR_YUV2RGB)
plt.imshow(img_output)

# %%
plt.imshow(Y_train[6][:, :, 0])

# %%
plt.imshow(dsutil.equalize_hist(rev_img))

# %%
random.uniform(0, 100)
# Out:
# 95.15309423580067

# %%
plt.imshow(img)

# %%
idx = 0
img = X_train[idx]
msk = Y_train[idx]
crop_images, mask_images = dsutil.random_crop(img, msk)

# %%
index = 0
tmp = np.hstack((crop_images[index],  mask_images[index]))
plt.imshow(tmp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-155-7eb984d56f60> in <module>()
#       1 index = 0
# ----> 2 tmp = np.hstack((crop_images[index],  mask_images[index]))
#       3 plt.imshow(tmp)
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/numpy/core/shape_base.py in hstack(tup)
#     286         return _nx.concatenate(arrs, 0)
#     287     else:
# --> 288         return _nx.concatenate(arrs, 1)
#     289
#     290 def stack(arrays, axis=0):
#
# ValueError: all the input arrays must have same number of dimensions

# %%
plt.imshow(crop_images[1])

# %%
plt.imshow(mask_images[1])

# %%
from multiprocessing import Pool

# %%
p = Pool(3)
ret = p.map(dsutil.negpos_reverse, X_train)
# ret = p.map(dsutil.equalize_hist, ret)

# %%
from tqdm import tqdm
equalized_list = []
for i in tqdm(range(len(ret)), total=len(ret)):
    equalized_list.append(dsutil.equalize_hist(ret[i]))
# Out:
# 100%|██████████| 670/670 [00:01<00:00, 531.58it/s]

# %%
plt.imshow(equalized_list[4])

# %%
X_train_crop = []
Y_train_crop = []
for i in tqdm(range(len(equalized_list)), total=len(equalized_list)):
    crop_

# %%
# X_train_ar = np.vstack(X_train)
# Y_train_ar = np.vstack(Y_train)
# X_test_ar = np.vstack(X_test)
# eq_ar = np.vstack(equalized_list)

# %%
# np.save('./data/nparrays/X_train.npy', X_train_ar)
# np.save('./data/nparrays/Y_train.npy', Y_train_ar)
# np.save('./data/nparrays/X_test.npy', X_test_ar)
# np.save('./data/nparrays/X_train_nprev_eqhist.npy', eq_ar)

# %%
idx = 100
plt.imshow(ret[idx])

# %%
plt.imshow(Y_train[idx][:, :, 0])

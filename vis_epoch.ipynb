# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
log = pd.read_csv('./log/2018_0308_1655/training.log')
log.plot(x='epoch', y=['loss', 'val_loss'])

# log.plot(x='epoch', y=['mean_iou', 'val_mean_iou'])

# %%
X_test = dsutil.get_test()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-224de55d346f> in <module>()
# ----> 1 X_test = dsutil.get_test()
#
# NameError: name 'dsutil' is not defined
